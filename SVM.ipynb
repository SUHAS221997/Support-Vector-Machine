# %%
#Mounting Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Importing Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Importing Packages
from sklearn.svm import SVC
from sklearn.metrics import *
from sklearn.model_selection import train_test_split, GridSearchCV

# %%
data=pd.read_csv("/content/drive/MyDrive/diabetes.csv")
data.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1
# 5                     0.201   30        0
# 6                     0.248   26        1
# 7                     0.134   29        0
# 8                     0.158   53        1
# 9                     0.232   54        1

# %%
data.shape
# Out:
# (768, 9)

# %% [markdown]
# Model Building

# %%
data.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
#Feature Variable
x=data.drop("Outcome",axis=1)
x.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age
# 0                     0.627   50
# 1                     0.351   31
# 2                     0.672   32
# 3                     0.167   21
# 4                     2.288   33

# %%
y=data["Outcome"]
y.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Outcome, dtype: int64

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=34)

# %%
model=SVC()

# %%
model.fit(x_train,y_train)
# Out:
# SVC()

# %%
pred=model.predict(x_test)

# %%
print(f"Accuracy:{accuracy_score(y_test,pred)}")
# Out:
# Accuracy:0.8051948051948052

# %% [markdown]
# Default Linear Model

# %%
model=SVC(kernel="linear")

# %%
model.fit(x_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
pred=model.predict(x_test)

# %%
print(f"Accuracy:{accuracy_score(y_test,pred)}")
# Out:
# Accuracy:0.8138528138528138

# %% [markdown]
# Default Ploynomial Kernel Model

# %%
model=SVC(kernel="poly")

# %%
model.fit(x_train,y_train)
# Out:
# SVC(kernel='poly')

# %%
pred=model.predict(x_test)

# %%
print(f"Accuracy:{accuracy_score(y_test,pred)}")
# Out:
# Accuracy:0.8138528138528138

# %% [markdown]
# Default SVM Model

# %%
model=SVC(kernel="sigmoid")

# %%
model.fit(x_train,y_train)
# Out:
# SVC(kernel='sigmoid')

# %%
pred=model.predict(x_test)

# %%
print(f"Accuracy:{accuracy_score(y_test,pred)}")
# Out:
# Accuracy:0.5108225108225108

# %%
#Hyper-parameter tuning

# %%
params={"kernel":["linear", "poly", "sigmoid", "rbf"]}

# %%
model=SVC(verbose=True)

# %%
hyperparameter=GridSearchCV(estimator=model, param_grid=params, cv=5,verbose=2)

# %%
hyperparameter.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [LibSVM][CV] END ......................................kernel=linear; total time=   3.1s
# [LibSVM][CV] END ......................................kernel=linear; total time=   2.7s
# [LibSVM][CV] END ......................................kernel=linear; total time=   2.8s
# [LibSVM][CV] END ......................................kernel=linear; total time=   3.8s
# [LibSVM][CV] END ......................................kernel=linear; total time=   4.6s
# [LibSVM][CV] END ........................................kernel=poly; total time=   0.0s
# [LibSVM][CV] END ........................................kernel=poly; total time=   0.0s
# [LibSVM][CV] END ........................................kernel=poly; total time=   0.0s
# [LibSVM][CV] END ........................................kernel=poly; total time=   0.0s
# [LibSVM][CV] END ........................................kernel=poly; total time=   0.0s
# [LibSVM][CV] END .....................................kernel=sigmoid; total time=   0.0s
# [LibSVM][CV] END .....................................kernel=sigmoid; total time=   0.0s
# [LibSVM][CV] END .....................................kernel=sigmoid; total time=   0.0s
# [LibSVM][CV] END .....................................kernel=sigmoid; total time=   0.0s
# [LibSVM][CV] END .....................................kernel=sigmoid; total time=   0.0s
# [LibSVM][CV] END .........................................kernel=rbf; total time=   0.0s
# [LibSVM][CV] END .........................................kernel=rbf; total time=   0.0s
# [LibSVM][CV] END .........................................kernel=rbf; total time=   0.0s
# [LibSVM][CV] END .........................................kernel=rbf; total time=   0.0s
# [LibSVM][CV] END .........................................kernel=rbf; total time=   0.0s
# [LibSVM]
# GridSearchCV(cv=5, estimator=SVC(verbose=True),
#              param_grid={'kernel': ['linear', 'poly', 'sigmoid', 'rbf']},
#              verbose=2)
